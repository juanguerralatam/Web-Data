# %%
import pandas as pd

input_csv = "videos_statistics.csv"       # change to your source file
output_csv = "download.csv"   # result will be saved here

df = pd.read_csv(input_csv)
df = df[['videoId','channelId']].copy()
df.to_csv(output_csv, index=False)
